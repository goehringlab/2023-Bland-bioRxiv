# %%
import sys
import pandas as pd
import numpy as np
sys.path.append('../../..')
from src import load_image, ImageQuant2
# %matplotlib widget

# %%
membg = np.loadtxt('../Quantification model calibration/membg6.txt')
cytbg = np.loadtxt('../Quantification model calibration/cytbg.txt')
calibration_factor = np.loadtxt('../Quantification model calibration/optogenetics_factors.txt')[6]

# %%
df = pd.read_csv('NEBD_Embryos_dataframe.csv')
df
# Out:
#     Unnamed: 0                                               Path    EmbryoID  \
# 0            0  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1556901861
# 1            1  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1556901937
# 2            2  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1556902036
# 3            3  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1556902453
# 4            4  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1556902969
# 5            5  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1559137737
# 6            6  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1559137889
# 7            7  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565356359
# 8            8  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565356740
# 9            9  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565356899
# 10          10  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565356990
# 11          11  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565357105
# 12          12  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565357282
# 13          13  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565358564
# 14          14  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565358687
# 15          15  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565359132
# 16          16  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565359289
# 17          17  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565359415
# 18          18  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565359558
# 19          19  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565359689
# 20          20  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565360221
# 21          21  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565360309
# 22          22  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565360584
# 23          23  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565360705
# 24          24  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565360828
# 25          25  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565360954
# 26          26  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565366847
# 27          27  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565367023
# 28          28  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565367111
# 29          29  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565367278
# 30          30  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565367567
# 31          31  /Users/blandt/Desktop/Data/Rundowns/PH rundown...  1565367659
#
#     Line    Date           RNAi
# 0     n2  190503             wt
# 1     n2  190503             wt
# 2     n2  190503             wt
# 3     n2  190503             wt
# 4     n2  190503             wt
# 5     n2  190529             wt
# 6     n2  190529             wt
# 7   od58  190809  1908081630xfp
# 8   od58  190809  1908081630xfp
# 9   od58  190809  1908081630xfp
# 10  od58  190809  1908081630xfp
# 11  od58  190809  1908081630xfp
# 12  od58  190809  1908081630xfp
# 13  od58  190809  1908081030xfp
# 14  od58  190809  1908081030xfp
# 15  od58  190809  1908081030xfp
# 16  od58  190809  1908081030xfp
# 17  od58  190809  1908081030xfp
# 18  od58  190809  1908081030xfp
# 19  od58  190809  1908081030xfp
# 20  od58  190809  1908081630xfp
# 21  od58  190809  1908081630xfp
# 22  od58  190809  1908081630xfp
# 23  od58  190809  1908081630xfp
# 24  od58  190809  1908081630xfp
# 25  od58  190809  1908081630xfp
# 26  od58  190809  1908081030xfp
# 27  od58  190809  1908081030xfp
# 28  od58  190809  1908081030xfp
# 29  od58  190809  1908081030xfp
# 30  od58  190809  1908081030xfp
# 31  od58  190809  1908081030xfp

# %% [markdown]
# ### Quantify

# %%
# Import data
paths = df.Path.to_list()
imgs = [load_image(p + '/af_corrected.tif') for p in paths]
rois = [np.loadtxt(p + '/ROI.txt') for p in paths]

# Run quantification
iq = ImageQuant2(img=imgs, roi=rois, cytbg=cytbg, membg=membg)
iq.quantify()

# Plot loss curve
iq.plot_losses(log=True)

# Save results
res = iq.compile_res(ids=df['EmbryoID'].to_list())
res['Membrane signal'] *= calibration_factor
res.to_csv('Quantification.csv')
# Out:
# 100%|██████████| 600/600 [00:07<00:00, 82.30it/s]
# <img src="data:image/png;base64,..." width="640">
