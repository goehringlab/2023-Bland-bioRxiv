# %%
import sys
sys.path.append('../../../src')
from image_quantification import *
from helpers import *
np.random.seed(12345)
# %matplotlib notebook

# %%
path1 = data_path + 'Imaging/Free mNG/210804_nwg378_tom4,5,60,500'
paths1 = direcslist(path1)
path2 = data_path + 'Imaging/Free mNG/220826_nwg378_tom4,5,60,500'
paths2 = direcslist(path2)
paths = paths1 + paths2
print(len(paths))
# Out:
# 17

# %%
imgs = [load_image(p + '/af_corrected.tif') for p in paths]
rois = [np.loadtxt(p + '/ROI_fit.txt') for p in paths]

# %%
iq = ImageQuant2(img=imgs, roi=rois)

# %%
iq.calibrate_cytoplasm()
# Out:
# 100%|██████████| 600/600 [00:04<00:00, 139.57it/s]

# %%
iq.plot_losses(log=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='Descent step', ylabel='log10(Mean square error)'>)

# %%
fig, ax = plt.subplots()
ax.plot(iq.cytbg)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.savetxt('cytbg.txt', iq.cytbg)
